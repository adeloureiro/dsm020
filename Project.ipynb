# %% [markdown]
# ## Course Work Project DSM020

# %% [markdown]
# #### Objective Between 1960 to 2019 who are the top performing ice goalkeepers?
#
# 1. Introduction
#
# 2. Who are the top performing goalkeepers?
#     1. Data preparation
#     2. Data analysis
#     3. Findings
#
# 3. What does it take to be a great ice goalie?
#     1. Data preparation
#     2. Data analysis
#     3. Findings
#
# 4. Short comings and recommendations
# 5. Conclusion
# ----

# %% [markdown]
# #### 1. Introduction
#
# I wanted to determine who the best ice hockey goalkeepers were between 1960 to 2019. I sourced my data publicly from the NHL website (http://www.nhl.com/stats/goalies).
#
# After the data was downloaded, I merged the data files and took time to understand all the variables. I changed the datatypes as needed and cleaned the file.
#
# Before starting my analysis, I did some data checks, then I ran a few statistical measures that defined who the top goalies were. These results were presented graphically.
#
# After I found out who the top goalkeepers were, I wanted to understand what makes an ice hockey goalkeeper great. For this I used online articles and blogs.

# %% [markdown]
# #### 2. Who are the top performing goalkeepers?

# %% [markdown]
# ##### A. Data preparation

# %%
import pandas as pd
import numpy as np
import csv
import os
import glob

import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#All data files are stored in the Data folder 
cwd = os. getcwd() + '\\Data'
print(cwd)
# Out:
# C:\Users\user\Documents\dsm020\Data

# %%
#List all the data files from the Data folder
path = os.chdir(cwd)
files = os.listdir(cwd)
print(files)
# Out:
# ['article.txt', 'Summary1960.xlsx', 'Summary1961.xlsx', 'Summary1962.xlsx', 'Summary1963.xlsx', 'Summary1964.xlsx', 'Summary1965.xlsx', 'Summary1966.xlsx', 'Summary1967.xlsx', 'Summary1968.xlsx', 'Summary1969.xlsx', 'Summary1970.xlsx', 'Summary1971.xlsx', 'Summary1972.xlsx', 'Summary1973.xlsx', 'Summary1974.xlsx', 'Summary1975.xlsx', 'Summary1976.xlsx', 'Summary1977.xlsx', 'Summary1978.xlsx', 'Summary1979.xlsx', 'Summary1980.xlsx', 'Summary1981.xlsx', 'Summary1982.xlsx', 'Summary1983.xlsx', 'Summary1984.xlsx', 'Summary1985.xlsx', 'Summary1986.xlsx', 'Summary1987.xlsx', 'Summary1988.xlsx', 'Summary1989.xlsx', 'Summary1990.xlsx', 'Summary1991.xlsx', 'Summary1992.xlsx', 'Summary1993.xlsx', 'Summary1994.xlsx', 'Summary1995.xlsx', 'Summary1996.xlsx', 'Summary1997.xlsx', 'Summary1998.xlsx', 'Summary1999.xlsx', 'Summary2000.xlsx', 'Summary2001.xlsx', 'Summary2002.xlsx', 'Summary2003.xlsx', 'Summary2005.xlsx', 'Summary2006.xlsx', 'Summary2007.xlsx', 'Summary2008.xlsx', 'Summary2009.xlsx', 'Summary2010.xlsx', 'Summary2011.xlsx', 'Summary2012.xlsx', 'Summary2013.xlsx', 'Summary2014.xlsx', 'Summary2015.xlsx', 'Summary2016.xlsx', 'Summary2017.xlsx', 'Summary2018.xlsx', 'Summary2019.xlsx']

# %%
excefile = [i for i in glob.glob('*.{}'.format('xlsx'))]

# %%
#Merge the data files 
goalie = pd.DataFrame() 

for i in excefile: 
    info = pd.read_excel(i,'Summary') #Summary is the name of all the sheets
    goalie = goalie.append(info) 
print(goalie)
# Out:
#               Player    Season Team S/C  GP  GS   W   L   T  OT  ...    Svs  \
# 0       Johnny Bower  19601961  TOR   L  58  58  33  15  10  --  ...  1,725
# 1         Glenn Hall  19601961  CHI   L  70  70  29  24  17  --  ...  2,026
# 2     Jacques Plante  19601961  MTL   L  40  40  23  11   6  --  ...  1,056
# 3       Gump Worsley  19601961  NYR   L  59  59  20  29   8  --  ...  1,990
# 4      Charlie Hodge  19601961  MTL   L  30  30  18   8   4  --  ...    802
# ..               ...       ...  ...  ..  ..  ..  ..  ..  ..  ..  ...    ...
# 82     Garret Sparks  20192020  VGK   L   1   0   0   0  --   0  ...     12
# 83  Michael Dipietro  20192020  VAN   L   1   0   0   0  --   0  ...      6
# 84  Kasimir Kaskisuo  20192020  TOR   L   1   1   0   1  --   0  ...     32
# 85       Oscar Dansk  20192020  VGK   L   1   1   0   1  --   0  ...     31
# 86    Calvin Pickard  20192020  DET   L   3   1   0   2  --   0  ...     59
#
#      GA    Sv%   GAA       TOI SO  G  A  P  PIM
# 0   145  0.922  2.50  3,480:00  2  0  0  0    0
# 1   177   0.92  2.53  4,194:00  6  0  1  1    0
# 2   112  0.904  2.80  2,400:00  2  0  0  0    2
# 3   190  0.913  3.29  3,468:51  1  0  0  0   10
# 4    74  0.916  2.47  1,798:00  4  0  0  0    0
# ..  ...    ...   ...       ... .. .. .. ..  ...
# 82    2  0.857  4.38     27:24  0  0  0  0    0
# 83    1  0.857  7.16      8:23  0  0  0  0    0
# 84    6  0.842  6.00     60:00  0  0  0  0    0
# 85    6  0.838  6.00     60:00  0  0  0  0    0
# 86   15  0.797  5.46    164:53  0  0  0  0    0
#
# [3803 rows x 21 columns]

# %%
#Data cleaning 
goalie1 = goalie.copy().reset_index(drop=True)

# %%
#I identified the variables that needed to be string, integar or float and corrected this 
goalie1.info()
goalie1.describe()
goalie1.head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3803 entries, 0 to 3802
# Data columns (total 21 columns):
# Player    3803 non-null object
# Season    3803 non-null int64
# Team      3803 non-null object
# S/C       3803 non-null object
# GP        3803 non-null int64
# GS        3803 non-null int64
# W         3803 non-null int64
# L         3803 non-null int64
# T         3803 non-null object
# OT        3803 non-null object
# SA        3803 non-null object
# Svs       3803 non-null object
# GA        3803 non-null int64
# Sv%       3803 non-null object
# GAA       3803 non-null float64
# TOI       3803 non-null object
# SO        3803 non-null int64
# G         3803 non-null int64
# A         3803 non-null int64
# P         3803 non-null int64
# PIM       3803 non-null int64
# dtypes: float64(1), int64(11), object(9)
# memory usage: 624.1+ KB
#               Player    Season Team S/C  GP  GS   W   L   T  OT  ...    Svs  \
# 0       Johnny Bower  19601961  TOR   L  58  58  33  15  10  --  ...  1,725
# 1         Glenn Hall  19601961  CHI   L  70  70  29  24  17  --  ...  2,026
# 2     Jacques Plante  19601961  MTL   L  40  40  23  11   6  --  ...  1,056
# 3       Gump Worsley  19601961  NYR   L  59  59  20  29   8  --  ...  1,990
# 4      Charlie Hodge  19601961  MTL   L  30  30  18   8   4  --  ...    802
# 5        Hank Bassen  19601961  DET   L  35  34  14  12   8  --  ...    844
# 6       Bruce Gamble  19601961  BOS   L  52  52  12  33   7  --  ...  1,588
# 7      Terry Sawchuk  19601961  DET   L  37  36  11  17   8  --  ...    975
# 8     Cesare Maniago  19601961  TOR   L   7   7   4   2   1  --  ...    219
# 9        Don Simmons  19601961  BOS   R  18  18   3   9   6  --  ...    535
# 10    Gerry McNamara  19601961  TOR   L   5   5   2   2   1  --  ...    135
# 11     Marcel Paille  19601961  NYR   L   4   4   1   2   1  --  ...    137
# 12     Jack McCartan  19601961  NYR   L   8   7   1   6   1  --  ...    205
# 13      Joe Schaefer  19601961  NYR   L   1   0   0   1   0  --  ...     27
# 14  Jerry Toppazzini  19601961  BOS   R   1   0   0   0   0  --  ...      0
# 15    Jacques Plante  19611962  MTL   L  70  70  42  14  14  --  ...  1,994
# 16      Johnny Bower  19611962  TOR   L  59  59  31  18  10  --  ...  1,675
# 17        Glenn Hall  19611962  CHI   L  70  70  31  26  13  --  ...  1,947
# 18      Gump Worsley  19611962  NYR   L  60  60  22  27   9  --  ...  1,791
# 19     Terry Sawchuk  19611962  DET   L  43  43  14  21   8  --  ...  1,116
# 20       Hank Bassen  19611962  DET   L  27  27   9  12   6  --  ...    693
# 21          Don Head  19611962  BOS   L  38  38   9  26   3  --  ...  1,149
# 22      Bruce Gamble  19611962  BOS   L  28  28   6  18   4  --  ...    882
# 23       Don Simmons  19611962  TOR   R   9   9   5   3   1  --  ...    266
# 24     Marcel Paille  19611962  NYR   L  10  10   4   4   2  --  ...    291
# 25    Gerry Cheevers  19611962  TOR   L   2   2   1   1   0  --  ...     64
# 26     Dan Olesevich  19611962  NYR   L   1   0   0   0   1  --  ...     17
# 27       Dave Dryden  19611962  NYR   L   1   0   0   1   0  --  ...     23
# 28       Ed Chadwick  19611962  BOS   L   4   4   0   3   1  --  ...    127
# 29        Glenn Hall  19621963  CHI   L  66  66  30  20  15  --  ...  1,807
#
#      GA    Sv%   GAA       TOI SO  G  A  P  PIM
# 0   145  0.922  2.50  3,480:00  2  0  0  0    0
# 1   177   0.92  2.53  4,194:00  6  0  1  1    0
# 2   112  0.904  2.80  2,400:00  2  0  0  0    2
# 3   190  0.913  3.29  3,468:51  1  0  0  0   10
# 4    74  0.916  2.47  1,798:00  4  0  0  0    0
# 5   100  0.894  2.93  2,046:00  0  0  1  1    6
# 6   193  0.892  3.71  3,118:00  0  0  0  0   14
# 7   112  0.897  3.13  2,148:00  2  0  1  1    8
# 8    17  0.928  2.43    418:58  0  0  0  0    2
# 9    58  0.902  3.23  1,077:27  1  0  0  0    6
# 10   12  0.918  2.42    298:00  0  0  0  0    2
# 11   16  0.895  4.00    240:00  0  0  0  0    0
# 12   35  0.854  4.77    440:00  1  0  0  0    0
# 13    3    0.9  3.64     49:24  0  0  0  0    0
# 14    0     --  0.00      0:33  0  0  0  0   10
# 15  166  0.923  2.37  4,200:00  4  0  0  0   14
# 16  151  0.917  2.56  3,540:00  2  0  1  1    4
# 17  184  0.914  2.63  4,200:00  9  0  0  0   12
# 18  172  0.912  2.92  3,531:18  2  0  0  0   12
# 19  141  0.888  3.28  2,580:00  5  0  0  0   12
# 20   75  0.902  2.78  1,620:00  3  0  0  0    8
# 21  158  0.879  4.16  2,280:00  2  0  0  0   14
# 22  121  0.879  4.32  1,680:00  1  0  0  0    4
# 23   21  0.927  2.33    540:00  1  0  0  0    0
# 24   28  0.912  2.80    600:00  0  0  0  0    0
# 25    6  0.914  3.00    120:00  0  0  0  0    0
# 26    2  0.895  4.12     29:09  0  0  0  0    0
# 27    3  0.885  4.55     39:33  0  0  0  0    0
# 28   22  0.852  5.50    240:00  0  0  0  0    0
# 29  161  0.918  2.47  3,907:50  5  0  0  0    0
#
# [30 rows x 21 columns]

# %% [markdown]
# When I tried to change the data type I came across as few problems that needed to be fixed:

# %%
#1. For Sv%, T and OT there were '--' in the columns, I converted this to numeric, all non-numerics became NAN
goalie1[['Sv%','T','OT']] = goalie1[['Sv%','T','OT']].apply(pd.to_numeric,errors='coerce')
goalie1['Sv%'] = goalie1['Sv%']*100

# %%
#2. SA and Svs had a comma that needed to be removed and needed to be changed to int 
cols = ['Svs', 'SA']
goalie1[cols] = goalie1[cols].replace({',': ''}, regex=True)

# %%
goalie1[['SA','Svs']] = goalie1[['SA','Svs']].astype(int)

# %%
#3. I pulled out only the first year from the column
goalie1['Season'] = goalie1['Season'].astype(str).str[:4]
goalie1['Season'] = goalie1['Season'].astype(int)

# %%
#4. TOI needed to become datetime 
goalie1['TOI'] = goalie1['TOI'].str.replace(',', '')

# %%
time = goalie1['TOI'].str.split(':', n = 1, expand = True) 
goalie1['min'] = time[0] 
goalie1['secs'] = time[1]

# %%
goalie1[['min','secs']] = goalie1[['min','secs']].astype(int)
goalie1['TOI_new'] = ((60 * goalie1['min']) + goalie1['secs']) / 60

# %%
#5. Some players play for more than one team, I chose to only look at the first team mentioned 
club = goalie1['Team'].str.split(',', n = 1, expand = True) 
goalie1['t1'] = club[0] 
goalie1['t2'] = club[1]

# %%
#6. In S/C there was '--' that needed to be removed, this is to stay as a string 
goalie1['S/C'] = goalie1['S/C'].str.replace('--','')

# %% [markdown]
# When it came to missing data, I found that Sv% had 10 rows where players have 0 shots against them, I removed these rows.
#
# OT(Overtime) and T(ties) are dependent on each other, if there is OT then there will be no T similarly the other way too.

# %%
#7. Missing data
drop_row = goalie1[goalie1['SA'] == 0].index
goalie1.drop(drop_row , inplace=True)

# %%
#8. Dealing with outliers

# %%
#droped all columns that I didn't need
goalie1 = goalie1.drop(columns = ['TOI','min','secs','t2','Team','OT','T'])

# %%
#I renamed all column and know whay each column means from https://en.wikipedia.org/wiki/Ice_hockey_statistics

new_cols = {
    't1':'team',                      #First listed team 
    'S/C':'catches',                  #Goalie catches Left or Right 
    'GP':'games_played',              #Games the goaltender played
    'GS':'games_started',             #Games the goaltender started
    'W':'wins',                       #Games won
    'L':'losses',                     #Games lost
    'SA':'shots_against',             #Shots against that player's team while player is on the ice
    'Svs':'saves',                    #Saved shots on goal
    'GA':'goals_against',             #Goals scored against the goaltender
    'Sv%':'save%',                    #Percentage of saves
    'GAA':'goals_against_average',    #Mean goals-per-60 minutes scored on the goaltender
    'TOI_new':'time(on ice)',         #Total time (mins) a player is on the ice during the playing of the game
    'SO':'shutouts',                  #Number of games where the goaltender had no goals against him and was the only goaltender to play
    'G':'goals ',                     #Goals each player scored
    'A':'assists',                    #Goals the player assisted in
    'P':'points',                     #Sum of goals and assists
    'PIM':'penalties(min)'            #Number of penalty minutes
    }

goalie1 = goalie1.rename(index=str, columns=new_cols)
goalie1.columns = map(str.lower, goalie1.columns)

# %%
#I doubled checked that points listed from 1-8 took effect
goalie1.head(10)
# Out:
#            player  season catches  games_played  games_started  wins  losses  \
# 0    Johnny Bower    1960       L            58             58    33      15
# 1      Glenn Hall    1960       L            70             70    29      24
# 2  Jacques Plante    1960       L            40             40    23      11
# 3    Gump Worsley    1960       L            59             59    20      29
# 4   Charlie Hodge    1960       L            30             30    18       8
# 5     Hank Bassen    1960       L            35             34    14      12
# 6    Bruce Gamble    1960       L            52             52    12      33
# 7   Terry Sawchuk    1960       L            37             36    11      17
# 8  Cesare Maniago    1960       L             7              7     4       2
# 9     Don Simmons    1960       R            18             18     3       9
#
#    shots_against  saves  goals_against  save%  goals_against_average  \
# 0           1870   1725            145   92.2                   2.50
# 1           2203   2026            177   92.0                   2.53
# 2           1168   1056            112   90.4                   2.80
# 3           2180   1990            190   91.3                   3.29
# 4            876    802             74   91.6                   2.47
# 5            944    844            100   89.4                   2.93
# 6           1781   1588            193   89.2                   3.71
# 7           1087    975            112   89.7                   3.13
# 8            236    219             17   92.8                   2.43
# 9            593    535             58   90.2                   3.23
#
#    shutouts  goals   assists  points  penalties(min)  time(on ice) team
# 0         2       0        0       0               0   3480.000000  TOR
# 1         6       0        1       1               0   4194.000000  CHI
# 2         2       0        0       0               2   2400.000000  MTL
# 3         1       0        0       0              10   3468.850000  NYR
# 4         4       0        0       0               0   1798.000000  MTL
# 5         0       0        1       1               6   2046.000000  DET
# 6         0       0        0       0              14   3118.000000  BOS
# 7         2       0        1       1               8   2148.000000  DET
# 8         0       0        0       0               2    418.966667  TOR
# 9         1       0        0       0               6   1077.450000  BOS

# %%
#I doubled checked I got the data types right and that the missing data rows were deleted, as well as the redundant colunms
goalie1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3793 entries, 0 to 3802
# Data columns (total 19 columns):
# player                   3793 non-null object
# season                   3793 non-null int32
# catches                  3793 non-null object
# games_played             3793 non-null int64
# games_started            3793 non-null int64
# wins                     3793 non-null int64
# losses                   3793 non-null int64
# shots_against            3793 non-null int32
# saves                    3793 non-null int32
# goals_against            3793 non-null int64
# save%                    3793 non-null float64
# goals_against_average    3793 non-null float64
# shutouts                 3793 non-null int64
# goals                    3793 non-null int64
# assists                  3793 non-null int64
# points                   3793 non-null int64
# penalties(min)           3793 non-null int64
# time(on ice)             3793 non-null float64
# team                     3793 non-null object
# dtypes: float64(3), int32(3), int64(10), object(3)
# memory usage: 548.2+ KB

# %% [markdown]
# Initially when I did my data spot checks I found a few years to be missing I then found out I duplicated 2000 data file and it had the wrong label. I picked this up by looking at my numbers if there was a number that didn't fit the trend I knew there was a problem. This was fixed by labelling the files right and now I see all the numbers are 'smooth'. i.e 1968 was sitting at a count of 70. Here I knew i did something wrong.

# %%
season = goalie1.season.value_counts().sort_index()
season
# Out:
# 1960    14
# 1961    14
# 1962    15
# 1963    15
# 1964    12
# 1965    19
# 1966    19
# 1967    31
# 1968    38
# 1969    34
# 1970    41
# 1971    41
# 1972    45
# 1973    49
# 1974    51
# 1975    53
# 1976    53
# 1977    53
# 1978    50
# 1979    69
# 1980    70
# 1981    66
# 1982    67
# 1983    69
# 1984    66
# 1985    50
# 1986    63
# 1987    63
# 1988    50
# 1989    70
# 1990    77
# 1991    50
# 1992    71
# 1993    79
# 1994    68
# 1995    78
# 1996    76
# 1997    73
# 1998    85
# 1999    83
# 2000    88
# 2001    89
# 2002    91
# 2003    94
# 2005    89
# 2006    84
# 2007    89
# 2008    89
# 2009    83
# 2010    87
# 2011    88
# 2012    82
# 2013    97
# 2014    92
# 2015    92
# 2016    94
# 2017    95
# 2018    93
# 2019    87
# Name: season, dtype: int64

# %% [markdown]
# ##### B. Data analysis

# %%
goalie1.describe()
# Out:
#             season  games_played  games_started         wins       losses  \
# count  3793.000000    3793.00000    3793.000000  3793.000000  3793.000000
# mean   1995.517005      28.79014      26.653572    12.126549    10.999209
# std      15.480909      21.05515      21.010915    11.030085     8.602708
# min    1960.000000       1.00000       0.000000     0.000000     0.000000
# 25%    1983.000000       9.00000       7.000000     2.000000     3.000000
# 50%    1997.000000      27.00000      24.000000     9.000000    10.000000
# 75%    2009.000000      45.00000      43.000000    20.000000    17.000000
# max    2019.000000      79.00000      78.000000    48.000000    48.000000
#
#        shots_against        saves  goals_against        save%  \
# count    3793.000000  3793.000000    3793.000000  3793.000000
# mean      796.909043   716.957553      79.951490    89.100791
# std       612.965228   556.236824      59.607106     4.423958
# min         1.000000     0.000000       0.000000     0.000000
# 25%       224.000000   198.000000      25.000000    87.800000
# 50%       718.000000   645.000000      74.000000    89.800000
# 75%      1260.000000  1135.000000     128.000000    91.200000
# max      2523.000000  2306.000000     282.000000   100.000000
#
#        goals_against_average     shutouts       goals       assists  \
# count            3793.000000  3793.000000  3793.000000  3793.000000
# mean                3.282259     1.432639     0.003427     0.701028
# std                 3.219832     1.976059     0.058451     1.127776
# min                 0.000000     0.000000     0.000000     0.000000
# 25%                 2.550000     0.000000     0.000000     0.000000
# 50%                 3.020000     1.000000     0.000000     0.000000
# 75%                 3.680000     2.000000     0.000000     1.000000
# max               184.620000    15.000000     1.000000    14.000000
#
#             points  penalties(min)  time(on ice)
# count  3793.000000     3793.000000   3793.000000
# mean      0.704456        4.346691   1608.782749
# std       1.132528        7.965993   1233.456481
# min       0.000000        0.000000      0.650000
# 25%       0.000000        0.000000    453.800000
# 50%       0.000000        2.000000   1456.233333
# 75%       1.000000        4.000000   2565.933333
# max      14.000000      113.000000   4696.550000

# %%
corr = goalie1.corr()

# Generate a mask for the upper triangle, True = do not show
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)]=True

f, ax = plt.subplots(figsize=(8, 7))

sns.heatmap(corr,mask=mask, cmap='Blues', linewidths=1.0, vmin=1.0, vmax=-1.0,cbar_kws={"shrink": 0.8})
plt.title('Correlation Matrix', fontsize=14)

#where I got the code from to help with masking the upper corner
#https://lost-stats.github.io/Presentation/heatmap_colored_correlation_matrix.html
# Out:
# Text(0.5, 1, 'Correlation Matrix')

# %%
# Player Stats 
player_pivot =  pd.pivot_table(data=goalie1, index='player', values=['games_played','games_started','wins','goals_against','save%','season','points'],
              aggfunc={'games_played':'sum','games_started':'sum','wins':'sum','goals_against':'sum','save%':'mean','season':'min','points':'mean'}).reset_index().rename(columns={'games_played': 'total games played', 'games_started': 'total games started','wins':'total wins','goals_against':'total goals against','save%':'average save percent','season':'season start','points':'average number points scored'})
player_pivot
# Out:
#               player  total games played  total games started  \
# 0         Aaron Dell                 107                   89
# 1      Adam Berkhoel                   9                    7
# 2        Adam Hauser                   1                    0
# 3         Adam Munro                  17                   17
# 4        Adam Werner                   2                    1
# ..               ...                 ...                  ...
# 668       Yann Danis                  55                   40
# 669  Yutaka Fukufuji                   4                    1
# 670    Yves Belanger                  78                   66
# 671        Zac Bierk                  47                   36
# 672    Zane McIntyre                   8                    3
#
#      total goals against  average number points scored  average save percent  \
# 0                    266                      0.250000             90.950000
# 1                     30                      0.000000             88.200000
# 2                      6                      0.000000             75.000000
# 3                     51                      0.500000             88.650000
# 4                      5                      0.000000             91.400000
# ..                   ...                           ...                   ...
# 668                  127                      0.000000             87.216667
# 669                    7                      0.000000             83.700000
# 670                  259                      0.833333             85.200000
# 671                  113                      0.166667             87.666667
# 672                   22                      0.000000             85.800000
#
#      season start  total wins
# 0            2016          48
# 1            2005           2
# 2            2005           0
# 3            2003           4
# 4            2019           1
# ..            ...         ...
# 668          2005          17
# 669          2006           0
# 670          1974          29
# 671          1997           9
# 672          2016           0
#
# [673 rows x 8 columns]

# %%
top100 = goalie1.sort_values[]
# Out:
#   File "<ipython-input-27-2ff76d0e694d>", line 1
#     top100 = goalie1.sort_values[]
#                                  ^
# SyntaxError: invalid syntax

# %%
top50 = player_pivot.reset_index().sort_values(['total games played'], ascending=[False]).set_index(['player']).nlargest(50,['total games played'])
top50
# Out:
#                         index  total games played  total games started  \
# player
# Martin Brodeur            422                1262                 1249
# Roberto Luongo            565                1044                 1014
# Patrick Roy               510                1029                 1003
# Ed Belfour                188                 963                  937
# Curtis Joseph             125                 943                  916
# Jose Theodore                          1635                      1.062500
# Bill Ranford                           2042                      1.600000
# Jonathan Quick                         1499                      1.461538
# Felix Potvin                           1686                      1.333333
# Miikka Kiprusoff                       1500                      0.833333
# Kirk McLean                            1893                      1.533333
# Ed Giacomin                            1672                      0.692308
# Mike Smith                             1575                      1.285714
# Bernie Parent                          1493                      0.923077
# Ron Hextall                            1723                      2.538462
# Dwayne Roloson                         1552                      1.000000
# Jean-Sebastien Giguere                 1423                      0.437500
# Greg Millen                            2259                      1.384615
# Eddie Johnston                         1852                      0.625000
# Jocelyn Thibault                       1508                      0.428571
# Ken Wregget                            1916                      1.411765
#
#                         average save percent  season start  total wins
# player
# Martin Brodeur                     91.085714          1993         689
# Roberto Luongo                     91.742105          1999         489
# Patrick Roy                        91.368421          1984         551
# Ed Belfour                         90.500000          1988         484
# Curtis Joseph                      90.300000          1989         454
# Henrik Lundqvist                   91.773333          2005         459
# Tony Esposito                      90.525000          1968         423
# John Vanbiesbrouck                 90.195000          1981         374
# Grant Fuhr                         88.442105          1981         403
# Marc-Andre Fleury                  91.218750          2003         466
# Sean Burke                         90.094444          1987         324
# Nikolai Khabibulin                 90.261111          1994         333
# Rogie Vachon                       89.487500          1966         353
# Gilles Meloche                     88.566667          1970         270
# Mike Vernon                        85.457895          1982         385
# Ryan Miller                        90.747059          2002         387
# Tom Barrasso                       88.900000          1983         369
# Chris Osgood                       90.435294          1993         401
# Dominik Hasek                      91.775000          1990         389
# Olie Kolzig                        88.441176          1989         303
# Andy Moog                          89.011111          1980         372
# Cam Ward                           90.614286          2005         334
# Tomas Vokoun                       90.220000          1996         300
# Evgeni Nabokov                     90.871429          1999         353
# Carey Price                        91.730769          2007         348
# Billy Smith                        89.161111          1971         305
# Kelly Hrudey                       89.400000          1983         271
# Mike Richter                       90.264286          1989         301
# Don Beaupre                        88.217647          1980         268
# Mike Liut                          88.100000          1979         293
# Pekka Rinne                        92.014286          2005         359
# Dan Bouchard                       88.971429          1972         286
# Kari Lehtonen                      91.450000          2003         310
# Craig Anderson                     91.182353          2002         289
# Jose Theodore                      87.987500          1995         286
# Bill Ranford                       89.020000          1985         240
# Jonathan Quick                     90.815385          2007         325
# Felix Potvin                       90.316667          1992         266
# Miikka Kiprusoff                   90.891667          2000         319
# Kirk McLean                        88.600000          1986         244
# Ed Giacomin                        89.792308          1965         290
# Mike Smith                         90.950000          2006         262
# Bernie Parent                      91.153846          1965         271
# Ron Hextall                        89.261538          1986         296
# Dwayne Roloson                     90.578571          1996         227
# Jean-Sebastien Giguere             90.968750          1996         262
# Greg Millen                        87.461538          1978         212
# Eddie Johnston                     89.218750          1962         236
# Jocelyn Thibault                   90.135714          1993         238
# Ken Wregget                        88.564706          1983         225

# %%
plt.figure(figsize=(30,5))
sns.boxplot(x='season',y='saves',data=goalie1,palette='YlGnBu')
plt.title('Correlation Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.figure(figsize=(25,5))
sns.barplot(x = 'season', y = 'saves', data = goalie1, palette='YlGnBu')
plt.title('Correlation Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# 1961          1       1              80   25200.000000
# 1962          2       2              58   25188.733333
# 1963          3       3              16   25192.016667
# 1964          5       5              56   25188.550000
# 1965          8       8              52   25179.866667
# 1966          2       2              42   25174.916667
# 1967          6       6             136   53212.633333
# 1968          8       8              94   54635.850000
# 1969         18      18             117   54647.116667
# 1970         12      12             141   65417.533333
# 1971         30      30             176   65429.683333
# 1972         28      28             162   74763.066667
# 1973         21      21             247   74742.550000
# 1974         40      40             319   86276.050000
# 1975         22      22             209   86219.516667
# 1976         34      34             226   86263.833333
# 1977         39      39             240   86265.766667
# 1978         47      47             397   81454.166667
# 1979         42      43             450  100548.533333
# 1980         65      65             283  100572.083333
# 1981         69      69             301  100623.100000
# 1982         67      67             344  100624.833333
# 1983         73      73             413  101630.150000
# 1984         46      46             374  101816.716667
# 1985         67      67             497   97565.433333
# 1986         66      66             718  101744.966667
# 1987         75      76             662  101805.983333
# 1988         89      89             591   98400.083333
# 1989         64      64             441  101769.016667
# 1990         68      68             403  101899.350000
# 1991         75      75             447   99796.916667
# 1992         91      91             493  121871.783333
# 1993         62      62             524  132359.550000
# 1994         30      30             193   75474.650000
# 1995         52      53             462  129172.683333
# 1996         50      50             452  129220.133333
# 1997         47      47             441  129311.766667
# 1998         51      52             375  134150.083333
# 1999         48      49             337  139117.033333
# 2000         51      52             304  148987.800000
# 2001         58      59             448  148960.883333
# 2002         39      39             385  149300.900000
# 2003         50      51             472  149268.300000
# 2005         72      73             413  148899.533333
# 2006         60      60             356  148971.333333
# 2007         72      72             234  148870.683333
# 2008         50      50             227  148872.683333
# 2009         60      60             182  149118.100000
# 2010         57      57             235  149003.283333
# 2011         65      66             122  149123.250000
# 2012         36      37              60   87183.250000
# 2013         63      64             174  149029.116667
# 2014         48      48             128  148847.800000
# 2015         52      52             114  148159.433333
# 2016         35      35             170  148233.950000
# 2017         60      60             188  153137.566667
# 2018         66      66             114  152822.183333
# 2019         39      40             142  130219.550000

# %% [markdown]
# ##### C. Findings
#
# This is what I found in the data and this is what it speaks to - waht are my findings and what makes this soooo wow

# %% [markdown]
# #### 3. What does it take to be a great ice goalie?

# %% [markdown]
# ##### A. Data preparation

# %%
import requests
from bs4 import BeautifulSoup

import nltk
from nltk.corpus import stopwords 

from nltk.tokenize import word_tokenize

import re
import string

stop_words = set(stopwords.words('english'))

# %% [markdown]
# art1 = requests.get('http://thegoalieguru.blogspot.com/2017/08/the-many-characteristics-needed-to-be.html')
# <br />art2 = requests.get('https://bleacherreport.com/articles/1734932-blueprint-for-the-perfect-nhl-goaltender')

# %% [markdown]
# Article 1
# <br />soup1 = BeautifulSoup(art1.content,'html.parser')
# <br />art1 = soup1.find(class_ ='post-body entry-content').text
# <br />print(art1)

# %% [markdown]
# Article 2
# <br />soup2 = BeautifulSoup(art2.content,'html.parser')
# <br />art2 = soup2.find(class_ ='organism contentStream').text
# <br />print(art2)

# %% [markdown]
# file = open('article.txt', 'w')
# <br />file.write(art1)
# <br />file.close()

# %% [markdown]
# file = open('article.txt', 'a')
# <br />file.write(art2)
# <br />file.close()

# %%
f = open('article.txt', 'r')
data = f.read()

# %% [markdown]
# After reading the data files, these articles would also need to be cleaned

# %%
#1. Make lower case and strip all trailing spaces
data = ' '.join([line.strip() for line in data.strip().splitlines() if line.strip()]).lower()

# %%
#2. Remove punctuation 
table = str.maketrans(dict.fromkeys(string.punctuation))  
data = data.translate(table)

# %%
# Stubborn em and en dashes needed to be removed 
data = data.replace("\u2013", "")#en dash
data = data.replace("\u2014", "")#em dash

# %%
' '.join(word.strip(string.punctuation) for word in data.split())
# Out:
# 'there arent many goaltenders who embody the attributes required to play the position better than jonathan quick hi gang a while back my editor threw me a curve when he asked me to write a column on the basic qualities that make a good goaltender my response youre kidding right i mean books have been written on that topic trying to do it justice in under 1200 words seemed crazy but the more i thought about it the more i warmed up to the idea it was a challenge and any goaltender worth his or her salt loves a challenge below is what i came up with let me know what you think the many characteristics needed to be a great goalie so you want to be a goaltender its an ageold question one that has challenged youngsters and their parents alike why would anyone volunteer to play a position generally considered one of the toughest in sports a position where you can only lose games not win them thats a lot to digest for a young child boy or girl just starting out ive addressed many aspects of the question over the years with my goalie guru column but when asked to take a look at the big picture i have to admit i was a bit overwhelmed its a daunting undertaking there are so many factors to consider suffice to say kids who dont play the position dont understand how tough goaltending can be much like coaches who never played in the nets it requires an entirely different skill set from goaliespecific skating to setting up on your angles youve got to follow a rockhard puck measuring only onebythree inches and stop it from entering a fourbysix foot goal and youve got to do it while trying to move around in bulky gear designed to protect you thats a tall order for most youngsters plus you cant take a shift off regular players make mistakes all the time but most of the time those gaffes dont result in goals kids rarely notice the errors of their linemates but they do notice the goals and if a goalie makes a mistake that leads directly to a goal that goalie is going to hear about it which is why goalies even young ones face tremendous pressure even on teams with enlightened coaches who try to shield their netminders from unwarranted criticism being the last line of defense is no picnic if you never play the position you never develop the appreciation of that particular brand of torture we live and die a little bit with each save and each goal that probably goes double for goalie parents so why play goalie its a simple question with a very complicated answer if i had a dime for every time a parent asked me how do i know my kid will stick with playing goal id be a very wealthy man but there are things that can help parents make an educated guess lets start with the individual child and consider the emotional mental and physical attributes that will assist a nascent goaltender there are a number of personality traits that are important if not essential to succeed between pipes different kids will possess these traits in varying degrees the challenge for goaltenders and their parents and their coaches is to nurture each quality to its fullest thats easier said than done below are the qualities that i recommend focusing on admittedly theres going to be some overlap that i think speaks to the complexity of the position emotional courage despite the improvement in goaltending gear getting hit with a puck can still hurt a lot much like a positional player cant shy away from the corners afraid that he might get pancaked by a defenseman or forechecker a goalie has to accept that he or she will occasionally get a stinger knowing that and still bearing down on each shot without flinching while remaining cool and calm takes guts toughness the ability to handle pressure is paramount youre going to get knocked down few goalies go through life without giving up bad goals and these days when goalies are becoming so dominant and goals are even harder to come by the pressure to be perfect has never been greater dealing with that requires intestinal fortitude confid ...

# %%
#3. Remove stop words 
word_tokens = word_tokenize(data) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
filtered_sentence = [] 
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(
', 'nurture', 'quality', 'fullest', 'thats', 'easier', 'said', 'done', 'qualities', 'recommend', 'focusing', 'admittedly', 'theres', 'going', 'overlap', 'think', 'speaks', 'complexity', 'position', 'emotional', 'courage', 'despite', 'improvement', 'goaltending', 'gear', 'getting', 'hit', 'puck', 'still', 'hurt', 'lot', 'much', 'like', 'positional', 'player', 'cant', 'shy', 'away', 'corners', 'afraid', 'might', 'get', 'pancaked', 'defenseman', 'forechecker', 'goalie', 'accept', 'occasionally', 'get', 'stinger', 'knowing', 'still', 'bearing', 'shot', 'without', 'flinching', 'remaining', 'cool', 'calm', 'takes', 'guts', 'toughness', 'ability', 'handle', 'pressure', 'paramount', 'youre', 'going', 'get', 'knocked', 'goalies', 'go', 'life', 'without', 'giving', 'bad', 'goals', 'days', 'goalies', 'becoming', 'dominant', 'goals', 'even', 'harder', 'come', 'pressure', 'perfect', 'never', 'greater', 'dealing', 'requires', 'intestinal', 'fortitude', 'confidence', 'kids', 'naturally', 'confident', 'others', 'gain', 'measure', 'hard', 'work', 'repetition', 'experiencing', 'success', 'often', 'results', 'confidence', 'isnt', 'ar ...

# %%
goal_wrds = ['goalie', 'goalies','goaltenders','goaltender','goal','good','take','many','often','youve','thats','one','puck','goals']

for word in list(filtered_sentence):
    if word in goal_wrds:
        filtered_sentence.remove(word)
print(filtered_sentence)
# Out:
# ['arent', 'embody', 'attributes', 'required', 'play', 'position', 'better', 'jonathan', 'quick', 'hi', 'gang', 'back', 'editor', 'threw', 'curve', 'asked', 'write', 'column', 'basic', 'qualities', 'make', 'response', 'youre', 'kidding', 'right', 'mean', 'books', 'written', 'topic', 'trying', 'justice', '1200', 'words', 'seemed', 'crazy', 'thought', 'warmed', 'idea', 'challenge', 'worth', 'salt', 'loves', 'challenge', 'came', 'let', 'know', 'think', 'characteristics', 'needed', 'great', 'want', 'ageold', 'question', 'challenged', 'youngsters', 'parents', 'alike', 'would', 'anyone', 'volunteer', 'play', 'position', 'generally', 'considered', 'toughest', 'sports', 'position', 'lose', 'games', 'win', 'lot', 'digest', 'young', 'child', 'boy', 'girl', 'starting', 'ive', 'addressed', 'aspects', 'question', 'years', 'guru', 'column', 'asked', 'look', 'big', 'picture', 'admit', 'bit', 'overwhelmed', 'daunting', 'undertaking', 'factors', 'consider', 'suffice', 'say', 'kids', 'dont', 'play', 'position', 'dont', 'understand', 'tough', 'goaltending', 'much', 'like', 'coaches', 'never', 'played', 'nets', 'requires', 'entirely', 'different', 'skill', 'set', 'goaliespecific', 'skating', 'setting', 'angles', 'got', 'follow', 'rockhard', 'measuring', 'onebythree', 'inches', 'stop', 'entering', 'fourbysix', 'foot', 'got', 'trying', 'move', 'around', 'bulky', 'gear', 'designed', 'protect', 'tall', 'order', 'youngsters', 'plus', 'cant', 'shift', 'regular', 'players', 'make', 'mistakes', 'time', 'time', 'gaffes', 'dont', 'result', 'kids', 'rarely', 'notice', 'errors', 'linemates', 'notice', 'makes', 'mistake', 'leads', 'directly', 'going', 'hear', 'even', 'young', 'ones', 'face', 'tremendous', 'pressure', 'even', 'teams', 'enlightened', 'coaches', 'try', 'shield', 'netminders', 'unwarranted', 'criticism', 'last', 'line', 'defense', 'picnic', 'never', 'play', 'position', 'never', 'develop', 'appreciation', 'particular', 'brand', 'torture', 'live', 'die', 'little', 'bit', 'save', 'probably', 'goes', 'double', 'parents', 'play', 'simple', 'question', 'complicated', 'answer', 'dime', 'every', 'time', 'parent', 'asked', 'know', 'kid', 'stick', 'playing', 'id', 'wealthy', 'man', 'things', 'help', 'parents', 'make', 'educated', 'guess', 'lets', 'start', 'individual', 'child', 'consider', 'emotional', 'mental', 'physical', 'attributes', 'assist', 'nascent', 'number', 'personality', 'traits', 'important', 'essential', 'succeed', 'pipes', 'different', 'kids', 'possess', 'traits', 'varying', 'degrees', 'challenge', 'parents', 'coaches', 'nurture', 'quality', 'fullest', 'easier', 'said', 'done', 'qualities', 'recommend', 'focusing', 'admittedly', 'theres', 'going', 'overlap', 'think', 'speaks', 'complexity', 'position', 'emotional', 'courage', 'despite', 'improvement', 'goaltending', 'gear', 'getting', 'hit', 'still', 'hurt', 'lot', 'much', 'like', 'positional', 'player', 'cant', 'shy', 'away', 'corners', 'afraid', 'might', 'get', 'pancaked', 'defenseman', 'forechecker', 'accept', 'occasionally', 'get', 'stinger', 'knowing', 'still', 'bearing', 'shot', 'without', 'flinching', 'remaining', 'cool', 'calm', 'takes', 'guts', 'toughness', 'ability', 'handle', 'pressure', 'paramount', 'youre', 'going', 'get', 'knocked', 'go', 'life', 'without', 'giving', 'bad', 'days', 'becoming', 'dominant', 'even', 'harder', 'come', 'pressure', 'perfect', 'never', 'greater', 'dealing', 'requires', 'intestinal', 'fortitude', 'confidence', 'kids', 'naturally', 'confident', 'others', 'gain', 'measure', 'hard', 'work', 'repetition', 'experiencing', 'success', 'results', 'confidence', 'isnt', 'arrogance', 'belief', 'matter', 'shots', 'may', 'gotten', 'behind', 'next', 'wont', 'enough', 'sure', 'abilities', 'exude', 'confidence', 'team', 'needs', 'believe', 'doesnt', 'starting', 'game', 'behind', '8ball', 'almost', 'certainly', 'play', 'tentatively', 'responsible', 'notion', 'taking', 'ownership', 'vital', 'great', 'patrick', 'roy', 'annoying', 'habit', 'showing', 'defense', 'felt', 'wa ...

# %%
listToStr = ' '.join([str(elem) for elem in filtered_sentence])

# %% [markdown]
# ##### B. Data analysis

# %%
from wordcloud import WordCloud

# %%
# word cloud
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(listToStr)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title('What makes a goalie great')
plt.show()

# %% [markdown]
# ##### C. Findings
#
# Based on the above word cloud it's evident that in order to be a great goalie, these two articles mention 'make time', 'kid' 'team' and a small mention towards parent.

# %% [markdown]
# #### 4. Short comings and recommendations

# %% [markdown]
# Nearly not enough articles were looked at, it would be recommended to look at at least 30 articles or blogs inorder to get a clearer understanding of the sentiment around descriptors that define what does it take to be a great ice hockey goalie.

# %% [markdown]
# #### 5. Conclusion
